# %%
#import Libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",None)

# %%
#Creating Dataframe
data_covid = pd.read_excel('Covid_Dataset.xlsx', header=0)
data_covid.head()
# Out:
#    cough  fever  sore_throat  shortness_of_breath  head_ache age_60_and_above  \
# 0      0      0            0                    0          0              Yes
# 1      1      0            0                    0          0              Yes
# 2      0      0            0                    0          0              Yes
# 3      1      1            0                    0          0              Yes
# 4      1      1            0                    0          0              Yes
#
#    gender         test_indication corona_result
# 0  female  Contact with confirmed      positive
# 1    male  Contact with confirmed      positive
# 2    male                  Abroad      positive
# 3    male                   Other      positive
# 4  female  Contact with confirmed      positive

# %%
data_covid.shape
# Out:
# (2137, 9)

# %%
data_covid.describe(include="all")
# Out:
#               cough        fever  sore_throat  shortness_of_breath  \
# count   2137.000000  2137.000000  2137.000000          2137.000000
# unique          NaN          NaN          NaN                  NaN
# top             NaN          NaN          NaN                  NaN
# freq            NaN          NaN          NaN                  NaN
# mean       0.419747     0.273280     0.038372             0.037436
# std        0.493633     0.445748     0.192137             0.189871
# min        0.000000     0.000000     0.000000             0.000000
# 25%        0.000000     0.000000     0.000000             0.000000
# 50%        0.000000     0.000000     0.000000             0.000000
# 75%        1.000000     1.000000     0.000000             0.000000
# max        1.000000     1.000000     1.000000             1.000000
#
#           head_ache age_60_and_above  gender test_indication corona_result
# count   2137.000000             2137    2137            2137          2137
# unique          NaN                2       3               3             2
# top             NaN               No  female           Other      positive
# freq            NaN             1159    1064            1290          1105
# mean       0.058493              NaN     NaN             NaN           NaN
# std        0.234729              NaN     NaN             NaN           NaN
# min        0.000000              NaN     NaN             NaN           NaN
# 25%        0.000000              NaN     NaN             NaN           NaN
# 50%        0.000000              NaN     NaN             NaN           NaN
# 75%        0.000000              NaN     NaN             NaN           NaN
# max        1.000000              NaN     NaN             NaN           NaN

# %% [markdown]
# **Pre processing the data**

# %%
# create a copy of the dataframe
data_covid_rev = pd.DataFrame.copy(data_covid)

# %%
data_covid_rev.duplicated().sum()
# Out:
# 1925

# %%
# Handle the missing value

# %%
data_covid_rev.isnull().sum()
# Out:
# cough                  0
# fever                  0
# sore_throat            0
# shortness_of_breath    0
# head_ache              0
# age_60_and_above       0
# gender                 0
# test_indication        0
# corona_result          0
# dtype: int64

# %%
data_covid_rev.dtypes
# Out:
# cough                   int64
# fever                   int64
# sore_throat             int64
# shortness_of_breath     int64
# head_ache               int64
# age_60_and_above       object
# gender                 object
# test_indication        object
# corona_result          object
# dtype: object

# %%
# convert categorical data into numerical
colname=[]
for x in data_covid_rev.columns:
    if data_covid_rev[x].dtype=='object':
        colname.append(x)
colname
# Out:
# ['age_60_and_above', 'gender', 'test_indication', 'corona_result']

# %%
# For preprocessing the data
from sklearn.preprocessing import LabelEncoder        
 
le=LabelEncoder()
 
for x in colname:
    data_covid_rev[x]=le.fit_transform(data_covid_rev[x])

# %%
# negative --> 0 
# positive --> 1

# %%
# Create X and Y
X = data_covid_rev.values[:,0:-1]  #--> 0 to -2
Y = data_covid_rev.values[:,-1]

# .values will return an array whereas .loc will return a df object
# arrays are lighter in weigth which indirectly help the model to build faster.

# %%
print(X.shape)
print(Y.shape)
# Out:
# (2137, 8)
# (2137,)

# %%
# Before Building the model, Do Scaling because it will improve the model.
from sklearn.preprocessing import StandardScaler
 
scaler = StandardScaler()
 
scaler.fit(X)
X = scaler.transform(X)

# %% [markdown]
# **Running a basic model**

# %% [markdown]
# # Model using Logistic Regression

# %%
from sklearn.model_selection import train_test_split
 
#Split the data into test and train
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,  # Default value -> test_size= 0.25
                                                    random_state=10)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1709, 8)
# (1709,)
# (428, 8)
# (428,)

# %%
from sklearn.linear_model import LogisticRegression
#create a model object
classifier = LogisticRegression()
#train the model object
classifier.fit(X_train,Y_train)      # fit is the function that is used for training the data

Y_pred = classifier.predict(X_test)
#print(Y_pred)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
print(cfm)
 
print("Classification report: ")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test, Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# [[161  49]
#  [ 93 125]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.77      0.69       210
#            1       0.72      0.57      0.64       218
#
#     accuracy                           0.67       428
#    macro avg       0.68      0.67      0.67       428
# weighted avg       0.68      0.67      0.67       428
#
# Accuracy of the model:  0.6682242990654206

# %% [markdown]
# ## Tunning
#
# ## Adjusting the Threshold

# %%
# store the predicted probabilities
y_pred_prob = classifier.predict_proba(X_test)
print(y_pred_prob)
# Out:
# [[5.43891575e-01 4.56108425e-01]
#  [4.05849970e-01 5.94150030e-01]
#  [2.78398734e-01 7.21601266e-01]
#  [3.07572236e-01 6.92427764e-01]
#  [5.25488360e-01 4.74511640e-01]
#  [3.67310049e-01 6.32689951e-01]
#  [5.25346586e-01 4.74653414e-01]
#  [7.33999306e-01 2.66000694e-01]
#  [3.34544795e-03 9.96654552e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [3.07572236e-01 6.92427764e-01]
#  [2.85172931e-01 7.14827069e-01]
#  [4.50376070e-01 5.49623930e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [4.23805456e-01 5.76194544e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [2.85172931e-01 7.14827069e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [1.59170993e-04 9.99840829e-01]
#  [3.67310049e-01 6.32689951e-01]
#  [6.09710663e-01 3.90289337e-01]
#  [4.98505603e-01 5.01494397e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [3.00048611e-03 9.96999514e-01]
#  [4.98647743e-01 5.01352257e-01]
#  [1.08008651e-02 9.89199135e-01]
#  [6.56203320e-03 9.93437967e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [4.58533849e-01 5.41466151e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [6.73512534e-05 9.99932649e-01]
#  [4.23944302e-01 5.76055698e-01]
#  [5.91401386e-01 4.08598614e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [2.63783448e-01 7.36216552e-01]
#  [6.33653807e-03 9.93663462e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.25488360e-01 4.74511640e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.51376443e-07 9.99999349e-01]
#  [2.57334437e-01 7.42665563e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [3.42713514e-01 6.57286486e-01]
#  [5.17135394e-01 4.82864606e-01]
#  [6.78587786e-01 3.21412214e-01]
#  [2.78398734e-01 7.21601266e-01]
#  [2.63783448e-01 7.36216552e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [4.50376070e-01 5.49623930e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [6.71243793e-01 3.28756207e-01]
#  [4.98647743e-01 5.01352257e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [4.50376070e-01 5.49623930e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [4.23944302e-01 5.76055698e-01]
#  [3.72563966e-03 9.96274360e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.25488360e-01 4.74511640e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.23805456e-01 5.76194544e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [3.67310049e-01 6.32689951e-01]
#  [4.50235332e-01 5.49764668e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [2.63783448e-01 7.36216552e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [2.47370255e-01 7.52629745e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.90280599e-01 5.09719401e-01]
#  [3.07572236e-01 6.92427764e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.17135394e-01 4.82864606e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [3.63960573e-03 9.96360394e-01]
#  [3.62220282e-02 9.63777972e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [2.47370255e-01 7.52629745e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [3.07572236e-01 6.92427764e-01]
#  [4.98505603e-01 5.01494397e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [7.54444754e-01 2.45555246e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [5.17135394e-01 4.82864606e-01]
#  [6.47111165e-01 3.52888835e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [6.54716945e-01 3.45283055e-01]
#  [3.72563966e-03 9.96274360e-01]
#  [2.09558446e-01 7.90441554e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [4.58533849e-01 5.41466151e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.83861397e-01 4.16138603e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [3.60109111e-01 6.39890889e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [5.56960962e-01 4.43039038e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [2.63783448e-01 7.36216552e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [3.67310049e-01 6.32689951e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [5.91401386e-01 4.08598614e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.25488360e-01 4.74511640e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.31999622e-01 5.68000378e-01]
#  [4.85545215e-03 9.95144548e-01]
#  [3.07572236e-01 6.92427764e-01]
#  [2.63783448e-01 7.36216552e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [5.25346586e-01 4.74653414e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [3.60109111e-01 6.39890889e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.56203320e-03 9.93437967e-01]
#  [7.33999306e-01 2.66000694e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.54716945e-01 3.45283055e-01]
#  [2.63783448e-01 7.36216552e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [3.62220282e-02 9.63777972e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [7.49907524e-05 9.99925009e-01]
#  [4.98647743e-01 5.01352257e-01]
#  [7.33999306e-01 2.66000694e-01]
#  [5.17135394e-01 4.82864606e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.98647743e-01 5.01352257e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [4.50376070e-01 5.49623930e-01]
#  [5.91401386e-01 4.08598614e-01]
#  [5.91401386e-01 4.08598614e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [2.63783448e-01 7.36216552e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.98647743e-01 5.01352257e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.90280599e-01 5.09719401e-01]
#  [3.07572236e-01 6.92427764e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [4.23805456e-01 5.76194544e-01]
#  [3.26522453e-02 9.67347755e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [5.25346586e-01 4.74653414e-01]
#  [3.00048611e-03 9.96999514e-01]
#  [4.90280599e-01 5.09719401e-01]
#  [2.27912147e-01 7.72087853e-01]
#  [4.50823194e-03 9.95491768e-01]
#  [7.33999306e-01 2.66000694e-01]
#  [3.07572236e-01 6.92427764e-01]
#  [1.20113580e-02 9.87988642e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [4.58533849e-01 5.41466151e-01]
#  [4.50376070e-01 5.49623930e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [2.63783448e-01 7.36216552e-01]
#  [5.88402957e-03 9.94115970e-01]
#  [2.08141556e-04 9.99791858e-01]
#  [4.58533849e-01 5.41466151e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [3.18933780e-01 6.81066220e-01]
#  [5.28773791e-03 9.94712262e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [4.58533849e-01 5.41466151e-01]
#  [2.36979477e-03 9.97630205e-01]
#  [3.60109111e-01 6.39890889e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.09710663e-01 3.90289337e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.01059304e-07 9.99999599e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [7.01560589e-01 2.98439411e-01]
#  [4.23944302e-01 5.76055698e-01]
#  [4.50376070e-01 5.49623930e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [5.25488360e-01 4.74511640e-01]
#  [2.63783448e-01 7.36216552e-01]
#  [4.50376070e-01 5.49623930e-01]
#  [4.98647743e-01 5.01352257e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [5.17135394e-01 4.82864606e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [3.85222418e-01 6.14777582e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.25346586e-01 4.74653414e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [5.17135394e-01 4.82864606e-01]
#  [4.05849970e-01 5.94150030e-01]
#  [5.91401386e-01 4.08598614e-01]
#  [3.07572236e-01 6.92427764e-01]
#  [3.67310049e-01 6.32689951e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.17135394e-01 4.82864606e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [7.54444754e-01 2.45555246e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [5.25488360e-01 4.74511640e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [2.78398734e-01 7.21601266e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [1.24362725e-02 9.87563727e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [3.72563966e-03 9.96274360e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [4.50376070e-01 5.49623930e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [3.18933780e-01 6.81066220e-01]
#  [6.09149629e-01 3.90850371e-01]
#  [4.58533849e-01 5.41466151e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.23944302e-01 5.76055698e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.71243793e-01 3.28756207e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [3.18933780e-01 6.81066220e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [3.42713514e-01 6.57286486e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.78587786e-01 3.21412214e-01]
#  [4.31999622e-01 5.68000378e-01]
#  [5.25488360e-01 4.74511640e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.23805456e-01 5.76194544e-01]
#  [6.71243793e-01 3.28756207e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [1.02527866e-02 9.89747213e-01]
#  [3.85222418e-01 6.14777582e-01]
#  [2.85172931e-01 7.14827069e-01]
#  [2.63783448e-01 7.36216552e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.17135394e-01 4.82864606e-01]
#  [7.54444754e-01 2.45555246e-01]
#  [6.71243793e-01 3.28756207e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [5.25488360e-01 4.74511640e-01]
#  [3.85222418e-01 6.14777582e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [5.17135394e-01 4.82864606e-01]
#  [6.09710663e-01 3.90289337e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [1.81731229e-03 9.98182688e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [5.17135394e-01 4.82864606e-01]
#  [1.61647538e-02 9.83835246e-01]
#  [4.58533849e-01 5.41466151e-01]
#  [2.47370255e-01 7.52629745e-01]
#  [4.23805456e-01 5.76194544e-01]
#  [3.37262416e-02 9.66273758e-01]
#  [3.42713514e-01 6.57286486e-01]
#  [6.33653807e-03 9.93663462e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [3.07572236e-01 6.92427764e-01]
#  [6.54716945e-01 3.45283055e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [3.67310049e-01 6.32689951e-01]
#  [4.23944302e-01 5.76055698e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [4.58533849e-01 5.41466151e-01]
#  [3.18933780e-01 6.81066220e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [5.25488360e-01 4.74511640e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.50376070e-01 5.49623930e-01]
#  [3.72563966e-03 9.96274360e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [6.09710663e-01 3.90289337e-01]
#  [5.25346586e-01 4.74653414e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [3.18933780e-01 6.81066220e-01]
#  [4.58533849e-01 5.41466151e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [2.85172931e-01 7.14827069e-01]
#  [5.91401386e-01 4.08598614e-01]
#  [5.65204235e-01 4.34795765e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [4.98505603e-01 5.01494397e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [6.17089453e-01 3.82910547e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [6.54716945e-01 3.45283055e-01]
#  [2.31746877e-04 9.99768253e-01]
#  [4.50235332e-01 5.49764668e-01]
#  [2.85144904e-03 9.97148551e-01]
#  [3.42713514e-01 6.57286486e-01]
#  [2.27912147e-01 7.72087853e-01]
#  [3.67310049e-01 6.32689951e-01]
#  [5.25488360e-01 4.74511640e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [3.00489623e-01 6.99510377e-01]
#  [4.31421354e-01 5.68578646e-01]
#  [5.91401386e-01 4.08598614e-01]
#  [7.54444754e-01 2.45555246e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [5.52182500e-01 4.47817500e-01]
#  [6.78587786e-01 3.21412214e-01]
#  [5.43891575e-01 4.56108425e-01]
#  [5.59573036e-03 9.94404270e-01]
#  [3.00489623e-01 6.99510377e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [1.57881278e-03 9.98421187e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [2.57334437e-01 7.42665563e-01]
#  [6.71243793e-01 3.28756207e-01]
#  [6.34958153e-01 3.65041847e-01]
#  [1.95657714e-03 9.98043423e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [4.31999622e-01 5.68000378e-01]
#  [4.98505603e-01 5.01494397e-01]
#  [1.24362725e-02 9.87563727e-01]
#  [4.77090950e-01 5.22909050e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [3.85222418e-01 6.14777582e-01]
#  [3.07572236e-01 6.92427764e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [6.94505195e-01 3.05494805e-01]
#  [4.58533849e-01 5.41466151e-01]]

# %%
# Trial and Error Approch --> decide you to take the best threshold value with the lowest Type 2 Error
for a in np.arange(0.4,0.61,0.01):
    predict_mine = np.where(y_pred_prob[:,1] > a, 1, 0) # acts as an if else statement
    cfm=confusion_matrix(Y_test, predict_mine)
    total_err=cfm[0,1]+cfm[1,0]  # Addition of Type 1 and Type 2 error
    print("Errors at threshold ", a, ":",total_err, " , type 2 error :", 
          cfm[1,0]," , type 1 error:", cfm[0,1])
# Out:
# Errors at threshold  0.4 : 127  , type 2 error : 36  , type 1 error: 91
# Errors at threshold  0.41000000000000003 : 134  , type 2 error : 43  , type 1 error: 91
# Errors at threshold  0.42000000000000004 : 133  , type 2 error : 43  , type 1 error: 90
# Errors at threshold  0.43000000000000005 : 133  , type 2 error : 43  , type 1 error: 90
# Errors at threshold  0.44000000000000006 : 122  , type 2 error : 44  , type 1 error: 78
# Errors at threshold  0.45000000000000007 : 119  , type 2 error : 57  , type 1 error: 62
# Errors at threshold  0.4600000000000001 : 123  , type 2 error : 71  , type 1 error: 52
# Errors at threshold  0.4700000000000001 : 123  , type 2 error : 71  , type 1 error: 52
# Errors at threshold  0.4800000000000001 : 134  , type 2 error : 84  , type 1 error: 50
# Errors at threshold  0.4900000000000001 : 142  , type 2 error : 93  , type 1 error: 49
# Errors at threshold  0.5000000000000001 : 142  , type 2 error : 93  , type 1 error: 49
# Errors at threshold  0.5100000000000001 : 139  , type 2 error : 98  , type 1 error: 41
# Errors at threshold  0.5200000000000001 : 139  , type 2 error : 98  , type 1 error: 41
# Errors at threshold  0.5300000000000001 : 136  , type 2 error : 109  , type 1 error: 27
# Errors at threshold  0.5400000000000001 : 136  , type 2 error : 109  , type 1 error: 27
# Errors at threshold  0.5500000000000002 : 153  , type 2 error : 128  , type 1 error: 25
# Errors at threshold  0.5600000000000002 : 153  , type 2 error : 128  , type 1 error: 25
# Errors at threshold  0.5700000000000002 : 155  , type 2 error : 131  , type 1 error: 24
# Errors at threshold  0.5800000000000002 : 159  , type 2 error : 138  , type 1 error: 21
# Errors at threshold  0.5900000000000002 : 159  , type 2 error : 138  , type 1 error: 21
# Errors at threshold  0.6000000000000002 : 157  , type 2 error : 138  , type 1 error: 19

# %%
y_pred_class=[]
for value in y_pred_prob[:,1]:
    if value > 0.456:
        y_pred_class.append(1)
    else:
        y_pred_class.append(0)
#print(y_pred_class)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cfm=confusion_matrix(Y_test,y_pred_class)
print(cfm)
acc=accuracy_score(Y_test, y_pred_class)
print("Accuracy of the model: ",acc)
print(classification_report(Y_test, y_pred_class))
# Out:
# [[148  62]
#  [ 57 161]]
# Accuracy of the model:  0.7219626168224299
#               precision    recall  f1-score   support
#
#            0       0.72      0.70      0.71       210
#            1       0.72      0.74      0.73       218
#
#     accuracy                           0.72       428
#    macro avg       0.72      0.72      0.72       428
# weighted avg       0.72      0.72      0.72       428

# %% [markdown]
# After Tuning in Logistic regression, we are getting the accuracy of 0.721, and as we can see that the recall for Class O & Class 1 is 0.70 and 0.74

# %% [markdown]
# # Model Using Decision Tree

# %%
from sklearn.model_selection import train_test_split
 
#Split the data into test and train
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,  # Default value -> test_size= 0.25
                                                    random_state=10)

# %%
# predicting using Decision Tree Classifier.
from sklearn.tree import DecisionTreeClassifier

model_DT = DecisionTreeClassifier(random_state=10,
                                   criterion="gini")

# fit the model on data and predict the values
model_DT.fit(X_train,Y_train)      # fit is the function that is used for training the data
Y_pred = model_DT.predict(X_test) # Validation Data
#print(Y_pred)
#print(list(zip(Y_test,Y_pred)))

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
 
cfm=confusion_matrix(Y_test,Y_pred)
print(cfm)
 
print("Classification report: ")
 
print(classification_report(Y_test,Y_pred))
 
acc=accuracy_score(Y_test, Y_pred)
print("Accuracy of the model: ",acc)
# Out:
# [[173  37]
#  [ 46 172]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81       210
#            1       0.82      0.79      0.81       218
#
#     accuracy                           0.81       428
#    macro avg       0.81      0.81      0.81       428
# weighted avg       0.81      0.81      0.81       428
#
# Accuracy of the model:  0.8060747663551402

# %% [markdown]
# ## Conclusion:
# As compared to **Logistic Regression**, Decision Tree is performed much better as we can see that the **Recall** & **f1-score** is **Higher** than **Logistic Regression**
